# %%
import pandas 
import seaborn 
# %matplotlib inline
import matplotlib.pyplot as plt 

df = pandas.read_csv( 'unknowns-ph-array.csv' )

g = seaborn.FacetGrid( df, col="substrate", row='ph', size=3, aspect=1)
g.map( seaborn.barplot, 'protein', 'rate', 'cofactor')

# %%
df = pandas.read_csv( '1oaa_data.csv' )
g = seaborn.FacetGrid( df, col="mutant_num", col_wrap=6, size=3, aspect=1 )
g.map( seaborn.barplot, 'substrate', 'rate' )
